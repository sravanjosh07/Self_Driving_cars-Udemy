# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanjosh07/Self_Driving_cars-Udemy/blob/Summer/Basic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(101)
points = 500
X = np.linspace(-3,3, points)
y = np.sin(X) + np.random.uniform(-0.5,0.5, points)
plt.scatter(X,y)

# %%
model = Sequential()
model.add(Dense(50, input_dim = 1, activation= 'sigmoid'))
model.add(Dense(50,  activation = 'sigmoid'))
model.add(Dense(1))

# %%
adam = Adam(lr = 0.01)
model.compile(loss= 'mse' , optimizer= adam)
model.fit(x = X, y = y, batch_size= 20, epochs= 10, validation_split= 0.05)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/10
# 24/24 [==============================] - 1s 11ms/step - loss: 0.2917 - val_loss: 0.8404
# Epoch 2/10
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2205 - val_loss: 1.0393
# Epoch 3/10
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1940 - val_loss: 0.7040
# Epoch 4/10
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1956 - val_loss: 1.2705
# Epoch 5/10
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1856 - val_loss: 0.5584
# Epoch 6/10
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1750 - val_loss: 1.3708
# Epoch 7/10
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1506 - val_loss: 0.8969
# Epoch 8/10
# ...

# %%
predictions = model.predict(X)
plt.scatter(X,y)
plt.plot(X, predictions, 'ro')
plt.show()
